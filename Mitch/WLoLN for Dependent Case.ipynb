# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def running_smpl_mean_plot(input_list,c):
    size = len(input_list)
    n = np.linspace(0,size-1,size)
    count = 0
    result_list = []
    while (count < size) :
        result_list.append(np.mean(input_list[0:count]))
        count += 1
    plt.figure()
    plt.plot(n,result_list,color="red")
##    plt.plot(n,c*((n+1)/(n+1)),color="blue")
    plt.grid()
    plt.show()
    
#parameters for P and Q
meanP = 100.0
sdP = 1.0
meanQ = 30.0
sdQ = 1.0
k = 1.0

N = 10000

Total = 10
count1 = 0
while (count1 < Total):
    np.random.seed(100*count1)
    #Z=Q/(P-kQ)
    Pdata = np.random.normal(meanP,sdP,N)
    Qdata = np.random.normal(meanQ,sdQ,N)
    Zdata = Qdata / (Pdata - k * Qdata)
    c0 = -k/((k*k)+((sdP/sdQ)*(sdP/sdQ)))
    running_smpl_mean_plot(Zdata,c0)
    count1 += 1
# Out:
# C:\Users\zecco\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\zecco\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
