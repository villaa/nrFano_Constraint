# %%
import numpy as np
import matplotlib.pyplot as plt
import resfuncRead as rfr

from data_check import band_check_nr, band_check_er
from Band_plots import NR_band_plot, ER_band_plot
from Yield_calc import Yield_NR, Yield_Er 
from bin_data_check import *

# %%
#For Nuclear Recoils 
N = 10000
ER, Yield = Yield_NR(N)

Erer, Yield_er = Yield_Er(N)

# %%
data = np.vstack((ER,Yield)).T
x = data[data[:,1]>=0, :]
a = x[:,1]
Enr = x[:,0]

#X = np.linspace(0,200,len(Enr))
X = Enr

data1 = np.vstack((Erer,Yield_er)).T
y = data1[data1[:,1]>=0, :]
b = y[:,1]
Ere = y[:,0]

Y = Ere
#Y = np.linspace(0,200,len(Ere))

print(len(ER))
# Out:
# 10000

# %%
NR_band_plot(Enr,a)

band_check_nr(a,1,X)
band_check_nr(a,2,X)
band_check_nr(a,3,X)


ER_band_plot(Ere,b)
band_check_er(b,1,Y)
band_check_er(b,2,Y)
band_check_er(b,3,Y)

for s in range(1,4):
    bin_check(s,N)
# Out:
# For 10000 number of data points
# Perecnt of data in nuclear band for 1 simga = 71.59
# Number of data points outside bands is: 2841
# -----------------------------------------------------------
# For 10000 number of data points
# Perecnt of data in nuclear band for 2 simga = 96.62
# Number of data points outside bands is: 338
# -----------------------------------------------------------
# For 10000 number of data points
# Perecnt of data in nuclear band for 3 simga = 99.82
# Number of data points outside bands is: 18
# -----------------------------------------------------------
# For 10000 number of data points
# Perecnt of data in electron band for 1 simga = 68.73
# Number of data points outside bands is: 3127
# -----------------------------------------------------------
# For 10000 number of data points
# Perecnt of data in electron band for 2 simga = 96.28
# Number of data points outside bands is: 372
# -----------------------------------------------------------
# For 10000 number of data points
# Perecnt of data in electron band for 3 simga = 99.8
# Number of data points outside bands is: 20
# -----------------------------------------------------------
# --------------------------------------------
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in 1 sigma
# -------------- 	 	-------------------
# 10.4-13.4 	 	 76.62889518413597
# 13.4-18.1 	 	 80.5228088159918
# 18.1-24.5 	 	 81.31600324939073
# 24.5-33.1 	 	 82.28675136116152
# 33.1-44.8 	 	 85.21828807150223
# 44.8-60.6 	 	 87.43608473338203
# 60.6-80.2 	 	 83.83233532934132
# 80.2-110 	 	 80.60200668896321
# 110-150 	 	 74.15730337078652
# --------------------------------------------
# --------------------------------------------
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in 2 sigma
# -------------- 	 	-------------------
# 10.4-13.4 	 	 96.2979683972912
# 13.4-18.1 	 	 96.77852348993288
# 18.1-24.5 	 	 97.37576772752652
# 24.5-33.1 	 	 97.8344562078922
# 33.1-44.8 	 	 98.51886137468179
# 44.8-60.6 	 	 99.02367586038565
# 60.6-80.2 	 	 98.83619435554263
# 80.2-110 	 	 98.51466765688824
# 110-150 	 	 98.51851851851852
# --------------------------------------------
# --------------------------------------------
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in 3 sigma
# -------------- 	 	-------------------
# 10.4-13.4 	 	 99.65823650034176
# 13.4-18.1 	 	 99.84599589322382
# 18.1-24.5 	 	 99.91601931555742
# 24.5-33.1 	 	 99.85533453887884
# 33.1-44.8 	 	 99.8639455782313
# 44.8-60.6 	 	 100.0
# 60.6-80.2 	 	 100.0
# 80.2-110 	 	 99.89127480293558
# 110-150 	 	 100.0
# --------------------------------------------
