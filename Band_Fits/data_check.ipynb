# %%
import numpy as np
import matplotlib.pyplot as plt
import resfuncRead as rfr

from data_check import *
from Band_plots import NR_band_plot, ER_band_plot
from Yield_calc import Yield_NR, Yield_Er 
from bin_data_check import * 
from bin_data_check import *

# %%
#For Nuclear Recoils 
N = 10000
ER, Yield = Yield_NR(N)

Erer, Yield_er = Yield_Er(N)

# %%
data = np.vstack((ER,Yield)).T
x = data[data[:,1]>=0, :]
c = x[x[:,0]>=10, :]
g = c[c[:,0]<=150, :]
a = g[:,1] #Yield 
Enr = g[:,0]


data1 = np.vstack((Erer,Yield_er)).T
y = data1[data1[:,1]>=0, :]
k = y[y[:,0]>=10,:]
g = k[k[:,0]<=150, :]
b = g[:,1]
Ere = g[:,0]


#Y = np.linspace(10,150,len(Ere))

# %%
NR_band_plot(Enr,a)
band_check(a,Enr,1,band_nr)
bin_check(a,Enr,1,band_nr)

'''
for s in range(1,4):
    band_check_nr(a,s,Enr)'''
    

ER_band_plot(Ere,b)
band_check(b,Ere,1,band_er)
bin_check(b,Ere,1,band_er)
# Out:
# For 9778 number of data points
# Perecnt of data in Nuclear for 1 simga = 72.49948864798527
# Number of data points outside bands is: 2689
# -----------------------------------------------------------
# --------------------------------------------
# 1 SIGMA Nuclear RECOIL BAND
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in band
# -------------- 	 	-------------------
# 10-13.4 	 	 67.17
# 13.4-18.1 	 	 68.12
# 18.1-24.5 	 	 67.41
# 24.5-33.1 	 	 68.78
# 33.1-44.8 	 	 73.13
# 44.8-60.6 	 	 76.40
# 60.6-80.2 	 	 76.58
# 80.2-110 	 	 80.34
# 110-150 	 	 78.33
# --------------------------------------------
# For 7303 number of data points
# Perecnt of data in Electron for 1 simga = 69.87539367383268
# Number of data points outside bands is: 2200
# -----------------------------------------------------------
# --------------------------------------------
# 1 SIGMA Electron RECOIL BAND
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in band
# -------------- 	 	-------------------
# 10-13.4 	 	 82.35
# 13.4-18.1 	 	 71.29
# 18.1-24.5 	 	 75.00
# 24.5-33.1 	 	 78.24
# 33.1-44.8 	 	 75.00
# 44.8-60.6 	 	 69.29
# 60.6-80.2 	 	 67.12
# 80.2-110 	 	 67.13
# 110-150 	 	 68.24
# --------------------------------------------
