# %%
import numpy as np
import matplotlib.pyplot as plt
import resfuncRead as rfr

from data_check import band_check_nr, band_check_er
from Band_plots import NR_band_plot, ER_band_plot
from Yield_calc import Yield_NR, Yield_Er 
from bin_data_check import *

# %%
#For Nuclear Recoils 
N = 10000
ER, Yield = Yield_NR(N)

Erer, Yield_er = Yield_Er(N)

# %%
data = np.vstack((ER,Yield)).T
x = data[data[:,1]>=0, :]
a = x[:,1]
Enr = x[:,0]

#X = np.linspace(0,200,len(Enr))
X = Enr

data1 = np.vstack((Erer,Yield_er)).T
y = data1[data1[:,1]>=0, :]
b = y[:,1]
Ere = y[:,0]

Y = Ere
#Y = np.linspace(0,200,len(Ere))

print(len(ER))
# Out:
# 10000

# %%
NR_band_plot(Enr,a)
for s in range(1,4):
    band_check_nr(a,s,Enr)
    
ER_band_plot(Ere,b)
for s in range(1,4):
    band_check_er(b,s,Ere)


for s in range(1,4):
    bin_check(s,N,Enr,a)
# Out:
# For 10000 number of data points
# Perecnt of data in nuclear band for 1 simga = 72.54
# Number of data points outside bands is: 2746
# -----------------------------------------------------------
# For 10000 number of data points
# Perecnt of data in nuclear band for 2 simga = 97.06
# Number of data points outside bands is: 294
# -----------------------------------------------------------
# For 10000 number of data points
# Perecnt of data in nuclear band for 3 simga = 99.86
# Number of data points outside bands is: 14
# -----------------------------------------------------------
# For 10000 number of data points
# Perecnt of data in electron band for 1 simga = 68.61
# Number of data points outside bands is: 3139
# -----------------------------------------------------------
# For 10000 number of data points
# Perecnt of data in electron band for 2 simga = 95.82
# Number of data points outside bands is: 418
# -----------------------------------------------------------
# For 10000 number of data points
# Perecnt of data in electron band for 3 simga = 99.83
# Number of data points outside bands is: 17
# -----------------------------------------------------------
# --------------------------------------------
# 1 SIGMA NUCLEAR RECOIL BAND
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in band
# -------------- 	 	-------------------
# 10.4-13.4 	 	 73.57
# 13.4-18.1 	 	 78.05
# 18.1-24.5 	 	 83.38
# 24.5-33.1 	 	 82.85
# 33.1-44.8 	 	 84.12
# 44.8-60.6 	 	 87.00
# 60.6-80.2 	 	 84.06
# 80.2-110 	 	 80.33
# 110-150 	 	 78.20
# --------------------------------------------
# --------------------------------------------
# 2 SIGMA NUCLEAR RECOIL BAND
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in band
# -------------- 	 	-------------------
# 10.4-13.4 	 	 96.66
# 13.4-18.1 	 	 96.18
# 18.1-24.5 	 	 97.77
# 24.5-33.1 	 	 97.93
# 33.1-44.8 	 	 98.83
# 44.8-60.6 	 	 99.14
# 60.6-80.2 	 	 98.91
# 80.2-110 	 	 99.02
# 110-150 	 	 96.56
# --------------------------------------------
# --------------------------------------------
# 3 SIGMA NUCLEAR RECOIL BAND
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in band
# -------------- 	 	-------------------
# 10.4-13.4 	 	 100.00
# 13.4-18.1 	 	 99.62
# 18.1-24.5 	 	 100.00
# 24.5-33.1 	 	 99.85
# 33.1-44.8 	 	 100.00
# 44.8-60.6 	 	 100.00
# 60.6-80.2 	 	 100.00
# 80.2-110 	 	 100.00
# 110-150 	 	 99.62
# --------------------------------------------
