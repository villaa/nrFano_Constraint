# %%
import numpy as np
import matplotlib.pyplot as plt
import resfuncRead as rfr

from data_check import band_check_nr, band_check_er
from Nr_plot import NR_band_plot, ER_band_plot
from Yield_calc import Yield_NR, Yield_er

# %%
#For Nuclear Recoils 
N = 100000
ER, Yield = Yield_NR(N)

Erer, Yield_er = Yield_er(N)

# %%
data = np.vstack((ER,Yield)).T
x = data[data[:,1]>=0, :]
a = x[:,1]
Enr = x[:,0]

#X = np.linspace(0,200,len(a))
X = Enr

data1 = np.vstack((Erer,Yield_er)).T
y = data1[data1[:,1]>=0, :]
b = y[:,1]
Ere = y[:,0]

Y = Ere

# %%
NR_band_plot(Enr,a)
band_check_nr(a,N,1,X)
band_check_nr(a,N,2,X)
band_check_nr(a,N,3,X)


ER_band_plot(Ere,b)
band_check_er(b,N,1,Y)
band_check_er(b,N,2,Y)
band_check_er(b,N,3,Y)
# Out:
# For 100000 number of data points
# Perecnt of data in nuclear band for 1 simga = 97.56
# Number of data points outside bands is: 2440
# -----------------------------------------------------------
# For 100000 number of data points
# Perecnt of data in nuclear band for 2 simga = 99.802
# Number of data points outside bands is: 198
# -----------------------------------------------------------
# For 100000 number of data points
# Perecnt of data in nuclear band for 3 simga = 99.993
# Number of data points outside bands is: 7
# -----------------------------------------------------------
# For 100000 number of data points
# Perecnt of data in electron band for 1 simga = 68.715
# Number of data points outside bands is: 31285
# -----------------------------------------------------------
# For 100000 number of data points
# Perecnt of data in electron band for 2 simga = 96.241
# Number of data points outside bands is: 3759
# -----------------------------------------------------------
# For 100000 number of data points
# Perecnt of data in electron band for 3 simga = 99.818
# Number of data points outside bands is: 182
# -----------------------------------------------------------
