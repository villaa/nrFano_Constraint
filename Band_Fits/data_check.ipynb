# %%
import numpy as np
import matplotlib.pyplot as plt
import resfuncRead as rfr

from data_check import *
from Band_plots import NR_band_plot, ER_band_plot
from Yield_calc import Yield_NR, Yield_Er 
from bin_data_check import * 
from bin_data_check import *

# %%
#For Nuclear Recoils 
N = 100000
ER, Yield = Yield_NR(N)

Erer, Yield_er = Yield_Er(N)

# %%
data = np.vstack((ER,Yield)).T
x = data[data[:,1]>=0, :]
c = x[x[:,0]>=10, :]
g = c[c[:,0]<=150, :]
Yield_nr = g[:,1] #Yield 
Enr = g[:,0]


data1 = np.vstack((Erer,Yield_er)).T
y = data1[data1[:,1]>=0, :]
k = y[y[:,0]>=10,:]
g = k[k[:,0]<=150, :]
Yield_er = g[:,1]
Ere = g[:,0]


#Y = np.linspace(10,150,len(Ere))

# %%
'''NR_band_plot(Enr,Yield_nr)
band_check(Yield_nr,Enr,1,band_nr)
bin_check(Yield_nr,Enr,1,band_nr)
'''
'''
for s in range(1,4):
    band_check_nr(a,s,Enr)'''
    

ER_band_plot(Ere,Yield_er)
band_check(Yield_er,Ere,1,band_er)
bin_check(Yield_er,Ere,1,band_er)
# Out:
# For 73682 number of data points
# Perecnt of data in ELECTRON for 1 simga = 71.22092234195597
# Number of data points outside bands is: 21205
# -----------------------------------------------------------
# --------------------------------------------
# 1 SIGMA ELECTRON RECOIL BAND
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in band 	 Percent from high 	 Percent from low
# -------------- 	 	------------------- 	------------------- 	-------------------
# 10-13.4 	 	 77.33 	 	 	 	69.19 	 	 	 85.47
# 13.4-18.1 	 	 78.53 	 	 	 	75.02 	 	 	 82.03
# 18.1-24.5 	 	 76.69 	 	 	 	74.27 	 	 	 79.12
# 24.5-33.1 	 	 75.92 	 	 	 	73.69 	 	 	 78.16
# 33.1-44.8 	 	 73.32 	 	 	 	72.62 	 	 	 74.02
# 44.8-60.6 	 	 68.85 	 	 	 	67.96 	 	 	 69.74
# 60.6-80.2 	 	 69.57 	 	 	 	70.78 	 	 	 68.36
# 80.2-110 	 	 69.98 	 	 	 	71.48 	 	 	 68.48
# 110-150 	 	 70.06 	 	 	 	72.72 	 	 	 67.39
# --------------------------------------------
