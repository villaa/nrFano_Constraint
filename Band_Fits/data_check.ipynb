# %%
import numpy as np
import matplotlib.pyplot as plt
import resfuncRead as rfr

from data_check import band_check_nr, band_check_er
from Band_plots import NR_band_plot, ER_band_plot
from Yield_calc import Yield_NR, Yield_Er 
from bin_data_check_nr import * 
from bin_data_check_er import *

# %%
#For Nuclear Recoils 
N = 10000
ER, Yield = Yield_NR(N)

Erer, Yield_er = Yield_Er(N)

# %%
data = np.vstack((ER,Yield)).T
x = data[data[:,1]>=0, :]
c = x[x[:,0]>=10, :]
g = c[c[:,0]<=150, :]
a = g[:,1] #Yield 
Enr = g[:,0]




'''data1 = np.vstack((Erer,Yield_er)).T
y = data1[data1[:,1]>=0, :]
k = y[y[:,0]>=10,:]
g = k[k[:,0]<=150, :]
b = g[:,1]
Ere = g[:,0]

Y = Ere
#Y = np.linspace(0,200,len(Ere))'''
# Out:
# 'data1 = np.vstack((Erer,Yield_er)).T\ny = data1[data1[:,1]>=0, :]\nk = y[y[:,0]>=10,:]\ng = k[k[:,0]<=150, :]\nb = g[:,1]\nEre = g[:,0]\n\nY = Ere\n#Y = np.linspace(0,200,len(Ere))'

# %%
NR_band_plot(Enr,a)

band_check_nr(a,1,Enr)
bin_check_NR(1,N,Enr,a)

'''
for s in range(1,4):
    band_check_nr(a,s,Enr)'''
    
'''
ER_band_plot(Ere,b)
for s in range(1,4):
    band_check_er(b,s,Ere)'''

'''
for s in range(1,4):
    bin_check_NR(s,N,Enr,a)
    #bin_check_ER(s,N,Ere,b)'''
# Out:
# For 9756 number of data points
# Perecnt of data in nuclear band for 1 simga = 72.35547355473555
# Number of data points outside bands is: 2697
# -----------------------------------------------------------
# --------------------------------------------
# 1 SIGMA NUCLEAR RECOIL BAND
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in band
# -------------- 	 	-------------------
# 10-13.4 	 	 80.60
# 13.4-18.1 	 	 78.26
# 18.1-24.5 	 	 81.69
# 24.5-33.1 	 	 84.98
# 33.1-44.8 	 	 83.97
# 44.8-60.6 	 	 84.93
# 60.6-80.2 	 	 85.05
# 80.2-110 	 	 79.38
# 110-150 	 	 72.37
# --------------------------------------------
