# %%
import numpy as np
import matplotlib.pyplot as plt
import resfuncRead as rfr

from data_check import band_check_nr, band_check_er
from Band_plots import NR_band_plot, ER_band_plot
from Yield_calc import Yield_NR, Yield_Er 
from bin_data_check_nr import * 
from bin_data_check_er import *

# %%
#For Nuclear Recoils 
N = 10000
ER, Yield = Yield_NR(N)

Erer, Yield_er = Yield_Er(N)

# %%
data = np.vstack((ER,Yield)).T
x = data[data[:,1]>=0, :]
c = x[x[:,0]>=10, :]
g = c[c[:,0]<=150, :]
a = g[:,1]
Enr = g[:,0]

#X = np.linspace(0,200,len(Enr))
X = Enr

data1 = np.vstack((Erer,Yield_er)).T
y = data1[data1[:,1]>=0, :]
k = y[y[:,0]>=10,:]
g = k[k[:,0]<=150, :]
b = g[:,1]
Ere = g[:,0]

Y = Ere
#Y = np.linspace(0,200,len(Ere))

# %%
NR_band_plot(Enr,a)
for s in range(1,4):
    band_check_nr(a,s,Enr)
    
ER_band_plot(Ere,b)
for s in range(1,4):
    band_check_er(b,s,Ere)


for s in range(1,4):
    bin_check(s,N,Enr,a)
    bin_check_ER(s,N,Ere,b)
# Out:
# For 9702 number of data points
# Perecnt of data in nuclear band for 1 simga = 72.80972995258709
# Number of data points outside bands is: 2638
# -----------------------------------------------------------
# For 9702 number of data points
# Perecnt of data in nuclear band for 2 simga = 96.79447536590393
# Number of data points outside bands is: 311
# -----------------------------------------------------------
# For 9702 number of data points
# Perecnt of data in nuclear band for 3 simga = 99.80416408987837
# Number of data points outside bands is: 19
# -----------------------------------------------------------
# For 7402 number of data points
# Perecnt of data in electron band for 1 simga = 69.83247770872737
# Number of data points outside bands is: 2233
# -----------------------------------------------------------
# For 7402 number of data points
# Perecnt of data in electron band for 2 simga = 95.96055120237773
# Number of data points outside bands is: 299
# -----------------------------------------------------------
# For 7402 number of data points
# Perecnt of data in electron band for 3 simga = 99.71629289381248
# Number of data points outside bands is: 21
# -----------------------------------------------------------
# --------------------------------------------
# 1 SIGMA NUCLEAR RECOIL BAND
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in band
# -------------- 	 	-------------------
# 10-13.4 	 	 73.56
# 13.4-18.1 	 	 78.84
# 18.1-24.5 	 	 84.43
# 24.5-33.1 	 	 81.95
# 33.1-44.8 	 	 82.76
# 44.8-60.6 	 	 86.07
# 60.6-80.2 	 	 85.74
# 80.2-110 	 	 79.08
# 110-150 	 	 75.40
# --------------------------------------------
# --------------------------------------------
# 1 SIGMA ELECTRON RECOIL BAND
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in band
# -------------- 	 	-------------------
# 10-13.4 	 	 81.69
# 13.4-18.1 	 	 79.03
# 18.1-24.5 	 	 75.29
# 24.5-33.1 	 	 79.75
# 33.1-44.8 	 	 78.26
# 44.8-60.6 	 	 81.65
# 60.6-80.2 	 	 75.00
# 80.2-110 	 	 79.58
# 110-150 	 	 80.57
# --------------------------------------------
# --------------------------------------------
# 2 SIGMA NUCLEAR RECOIL BAND
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in band
# -------------- 	 	-------------------
# 10-13.4 	 	 94.37
# 13.4-18.1 	 	 97.42
# 18.1-24.5 	 	 97.62
# 24.5-33.1 	 	 97.37
# 33.1-44.8 	 	 98.46
# 44.8-60.6 	 	 98.84
# 60.6-80.2 	 	 98.54
# 80.2-110 	 	 98.44
# 110-150 	 	 97.22
# --------------------------------------------
# --------------------------------------------
# 2 SIGMA ELECTRON RECOIL BAND
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in band
# -------------- 	 	-------------------
# 10-13.4 	 	 98.59
# 13.4-18.1 	 	 97.58
# 18.1-24.5 	 	 98.82
# 24.5-33.1 	 	 96.28
# 33.1-44.8 	 	 96.32
# 44.8-60.6 	 	 95.82
# 60.6-80.2 	 	 96.48
# 80.2-110 	 	 96.19
# 110-150 	 	 97.02
# --------------------------------------------
# --------------------------------------------
# 3 SIGMA NUCLEAR RECOIL BAND
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in band
# -------------- 	 	-------------------
# 10-13.4 	 	 99.44
# 13.4-18.1 	 	 99.82
# 18.1-24.5 	 	 99.84
# 24.5-33.1 	 	 100.00
# 33.1-44.8 	 	 100.00
# 44.8-60.6 	 	 99.85
# 60.6-80.2 	 	 99.82
# 80.2-110 	 	 100.00
# 110-150 	 	 99.60
# --------------------------------------------
# --------------------------------------------
# 3 SIGMA ELECTRON RECOIL BAND
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in band
# -------------- 	 	-------------------
# 10-13.4 	 	 100.00
# 13.4-18.1 	 	 100.00
# 18.1-24.5 	 	 100.00
# 24.5-33.1 	 	 99.59
# 33.1-44.8 	 	 100.00
# 44.8-60.6 	 	 98.37
# 60.6-80.2 	 	 99.61
# 80.2-110 	 	 99.38
# 110-150 	 	 100.00
# --------------------------------------------
