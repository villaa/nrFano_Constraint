# %%
import numpy as np
import matplotlib.pyplot as plt
import resfuncRead as rfr
from scipy.stats import kde

from data_check import *
from Band_plots import *
from Yield_calc import Yield_NR, Yield_Er 
from bin_data_check import * 
 
from Yield_bin import * 
from Bin_Corr import *

# %%
N = 10000
#ER, Yield = Yield_NR(N)

Ere, Yield_er,EQ,EP = Yield_Er(N) #Electron Recoil Band. 

EP_EQ_plot(EP,EQ) # Plot EQ EP Spcace 

Corr(EP,EQ) # calculate correlation coefficent between EQ and EP
# Out:
# CORRELATION COEFFICENT FOR EQ AND EP
# ---------------------------------------------------------------
# Bin(keV) 	 Numpy Coefficient 	 Brute Force Check
# ---------------------------------------------------------------
# 10-13.4 	 	 nan 	 	 	 nan
# 13.4-18.1 	 	 nan 	 	 	 nan
# 18.1-24.5 	 	 -0.09 	 	 	 -0.09
# 24.5-33.1 	 	 0.64 	 	 	 0.64
# 33.1-44.8 	 	 0.75 	 	 	 0.75
# 44.8-60.6 	 	 0.73 	 	 	 0.73
# 60.6-80.2 	 	 0.32 	 	 	 0.32
# 80.2-110 	 	 0.67 	 	 	 0.67

# %%
'''NR_band_plot(Enr,Yield_nr)
band_check(Yield_nr,Enr,1,band_nr)
bin_check(Yield_nr,Enr,1,band_nr)'''


#for s in range(1,4):
   # band_check_nr(a,s,Enr)
    
ER_band_plot(Ere,Yield_er,N)
#band_check(Yield_er,Ere,1,band_er)
#data= bin_check(Yield_er,Ere,1,band_er)
bin_check(Yield_er,Ere,1,band_er)
#Hist(data)


#NR_ER_plot(Enr,Ere,Yield_nr,Yield_er)
# Out:
# My program took 0.02928272883097331  mintues to run
# 126 126 1173
# 127 201 1278
# 133 200 1251
# 152 214 1318
# 148 225 1245
# 162 285 1249
# 130 290 1228
# 124 304 1227
# --------------------------------------------
# 1 SIGMA ELECTRON RECOIL BAND
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in band 	 Percent from high 	 Percent from low
# -------------- 	 	------------------- 	------------------- 	-------------------
# 10-13.4 	 	 78.52 	 ± 1.20 % 	 78.52 	 ± 1.81 	 78.52 	 ± 1.81
# 13.4-18.1 	 	 74.33 	 ± 1.22 % 	 80.13 	 ± 1.67 	 68.54 	 ± 2.04
# 18.1-24.5 	 	 73.38 	 ± 1.25 % 	 78.74 	 ± 1.74 	 68.03 	 ± 2.07
# 24.5-33.1 	 	 72.23 	 ± 1.23 % 	 76.93 	 ± 1.76 	 67.53 	 ± 2.03
# 33.1-44.8 	 	 70.04 	 ± 1.30 % 	 76.22 	 ± 1.83 	 63.86 	 ± 2.18
# 44.8-60.6 	 	 64.21 	 ± 1.36 % 	 74.06 	 ± 1.90 	 54.36 	 ± 2.37
# 60.6-80.2 	 	 65.80 	 ± 1.35 % 	 78.83 	 ± 1.76 	 52.77 	 ± 2.42
# 80.2-110 	 	 65.12 	 ± 1.36 % 	 79.79 	 ± 1.72 	 50.45 	 ± 2.46
# --------------------------------------------
#                0         1         2         3
