# %%
import numpy as np
import matplotlib.pyplot as plt
import resfuncRead as rfr
from scipy.stats import gaussian_kde

from data_check import *
from Band_plots import *
from Yield_calc import Yield_NR, Yield_Er 
from bin_data_check import * 
from bin_data_check import *

# %%
#For Nuclear Recoils 
N = 10000
ER, Yield = Yield_NR(N)

Erer, Yield_er,EQ = Yield_Er(N)

# %%
data = np.vstack((ER,Yield)).T
x = data[data[:,1]>-0.3, :]
c = x[x[:,0]>=10, :]
g = c[c[:,0]<=150, :]
Yield_nr = g[:,1] #Yield 
Enr = g[:,0]


data1 = np.vstack((Erer,Yield_er)).T
y = data1[data1[:,1]>0, :]
k = y[y[:,0]>=10,:]
g = k[k[:,0]<=150, :]
Yield_er = g[:,1]
Ere = g[:,0]


#Y = np.linspace(10,150,len(Ere))

# %%
'''NR_band_plot(Enr,Yield_nr)
band_check(Yield_nr,Enr,1,band_nr)'''
#bin_check(Yield_nr,Enr,1,band_nr)

'''
for s in range(1,4):
    band_check_nr(a,s,Enr)'''
    
ER_band_plot(Ere,Yield_er,N)
band_check(Yield_er,Ere,1,band_er)
bin_check(Yield_er,Ere,1,band_er)

#NR_ER_plot(Enr,Ere,Yield_nr,Yield_er)
# Out:
# For 9788 number of data points
# Perecnt of data in ELECTRON for 1 simga = 67.80751941152431
# Number of data points outside bands is: 3151
# -----------------------------------------------------------
# 51 17 247
# 56 49 346
# 72 60 399
# 119 84 628
# 162 140 899
# 198 205 1151
# 238 217 1339
# 333 370 2100
# 283 497 2679
# --------------------------------------------
# 1 SIGMA ELECTRON RECOIL BAND
# --------------------------------------------
# Bin Spacing (keV) 	 Percent in band 	 Percent from high 	 Percent from low
# -------------- 	 	------------------- 	------------------- 	-------------------
# 10-13.4 	 	 72.47 	 ± 8.54 % 	 	 58.70 	 	 	 86.23
# 13.4-18.1 	 	 69.65 	 ± 7.74 % 	 	 67.63 	 	 	 71.68
# 18.1-24.5 	 	 66.92 	 ± 8.78 % 	 	 63.91 	 	 	 69.92
# 24.5-33.1 	 	 67.68 	 ± 8.71 % 	 	 62.10 	 	 	 73.25
# 33.1-44.8 	 	 66.41 	 ± 8.94 % 	 	 63.96 	 	 	 68.85
# 44.8-60.6 	 	 64.99 	 ± 9.41 % 	 	 65.60 	 	 	 64.38
# 60.6-80.2 	 	 66.02 	 ± 9.05 % 	 	 64.45 	 	 	 67.59
# 80.2-110 	 	 66.52 	 ± 8.87 % 	 	 68.29 	 	 	 64.76
# 110-150 	 	 70.88 	 ± 7.91 % 	 	 78.87 	 	 	 62.90
# --------------------------------------------
