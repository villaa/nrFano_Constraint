# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
t = np.arange(-2*np,2*np.pi)

x = np.cos(3*t)
y = np.sin(t)

# %%
plt.plot(x,y)

# %%
print(t)
# Out:
# [0. 1. 2. 3. 4. 5. 6.]
